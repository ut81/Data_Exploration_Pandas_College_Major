# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd

# %%
df=pd.read_csv("salaries_by_college_major.csv")
df.head()
# Out:
#      Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0             Accounting                 46000.0                   77100.0
# 1  Aerospace Engineering                 57700.0                  101000.0
# 2            Agriculture                 42600.0                   71900.0
# 3           Anthropology                 36800.0                   61500.0
# 4           Architecture                 41600.0                   76800.0
#
#    Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 0                            42200.0                           152000.0
# 1                            64300.0                           161000.0
# 2                            36300.0                           150000.0
# 3                            33800.0                           138000.0
# 4                            50600.0                           136000.0
#
#       Group
# 0  Business
# 1      STEM
# 2  Business
# 3      HASS
# 4  Business

# %%
df.shape
# Out:
# (51, 6)

# %%
df.describe()
# Out:
#        Starting Median Salary  Mid-Career Median Salary  \
# count               50.000000                  50.00000
# mean             44310.000000               74786.00000
# std               9360.866217               16088.40386
# min              34000.000000               52000.00000
# 25%              37050.000000               60825.00000
# 50%              40850.000000               72000.00000
# 75%              49875.000000               88750.00000
# max              74300.000000              107000.00000
#
#        Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary
# count                          50.000000                          50.000000
# mean                        43408.000000                      142766.000000
# std                         12000.779567                       27851.249267
# min                         26700.000000                       96400.000000
# 25%                         34825.000000                      124250.000000
# ...

# %%
df.tail()
# Out:
#       Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 46             Psychology                 35900.0                   60400.0
# 47               Religion                 34100.0                   52000.0
# 48              Sociology                 36500.0                   58200.0
# 49                Spanish                 34000.0                   53100.0
# 50  Source: PayScale Inc.                     NaN                       NaN
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary Group
# 46                            31600.0                           127000.0  HASS
# 47                            29700.0                            96400.0  HASS
# 48                            30700.0                           118000.0  HASS
# 49                            31000.0                            96400.0  HASS
# 50                                NaN                                NaN   NaN

# %%
df.columns
# Out:
# Index(['Undergraduate Major', 'Starting Median Salary',
#        'Mid-Career Median Salary', 'Mid-Career 10th Percentile Salary',
#        'Mid-Career 90th Percentile Salary', 'Group'],
#       dtype='object')

# %%
df.isna()
# Out:
#     Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0                 False                   False                     False
# 1                 False                   False                     False
# 2                 False                   False                     False
# 3                 False                   False                     False
# 4                 False                   False                     False
# 5                 False                   False                     False
# 6                 False                   False                     False
# 7                 False                   False                     False
# 8                 False                   False                     False
# 9                 False                   False                     False
# 10                False                   False                     False
# 11                False                   False                     False
# ...

# %%
clean_df=df.dropna()

# %%
clean_df.isna()
# Out:
#     Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0                 False                   False                     False
# 1                 False                   False                     False
# 2                 False                   False                     False
# 3                 False                   False                     False
# 4                 False                   False                     False
# 5                 False                   False                     False
# 6                 False                   False                     False
# 7                 False                   False                     False
# 8                 False                   False                     False
# 9                 False                   False                     False
# 10                False                   False                     False
# 11                False                   False                     False
# ...

# %%
clean_df.shape
# Out:
# (50, 6)

# %%
clean_df["Starting Median Salary"].max()
# Out:
# 74300.0

# %%
clean_df["Starting Median Salary"].idxmax()
# Out:
# 43

# %%
print(f"the degree has highest starting salary is {clean_df['Undergraduate Major'].loc[43]}")
# Out:
# the degree has highest starting salary is Physician Assistant

# %%
corresponding_value = clean_df.loc[clean_df['Starting Median Salary'] == clean_df["Starting Median Salary"].max(), 'Undergraduate Major'].values[0]

# %%
corresponding_value
# Out:
# 'Physician Assistant'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
clean_df["Mid-Career Median Salary"].max()
# Out:
# 107000.0

# %%
clean_df["Mid-Career Median Salary"].idxmax()
# Out:
# 8

# %%
clean_df["Undergraduate Major"].loc[8]
# Out:
# 'Chemical Engineering'

# %%
clean_df["Starting Median Salary"].min()
# Out:
# 34000.0

# %%
coresponding_value=clean_df.loc[clean_df["Mid-Career Median Salary"]==clean_df["Mid-Career Median Salary"].max(),'Undergraduate Major'].values[0]

# %%
coresponding_value
# Out:
# 'Chemical Engineering'

# %%
coresponding_value=clean_df.loc[clean_df["Starting Median Salary"]==clean_df["Starting Median Salary"].min(),'Undergraduate Major'].values[0]

# %%
coresponding_value
# Out:
# 'Spanish'

# %%
Spread_col=clean_df["Mid-Career 90th Percentile Salary"]-clean_df["Mid-Career 10th Percentile Salary"]
Spread_col
# Out:
# 0     109800.0
# 1      96700.0
# 2     113700.0
# 3     104200.0
# 4      85400.0
# 5      96200.0
# 6      98100.0
# 7     108200.0
# 8     122100.0
# 9     102700.0
# 10     84600.0
# 11    105500.0
# 12     95900.0
# 13     98000.0
# 14    114700.0
# 15     74800.0
# 16    116300.0
# 17    159400.0
# 18     72700.0
# 19     98700.0
# 20     99600.0
# 21    102100.0
# 22    147800.0
# 23     70000.0
# 24     92000.0
# 25    111000.0
# 26     76000.0
# 27     66400.0
# 28    112000.0
# 29     88500.0
# 30    115900.0
# 31     84500.0
# 32     71300.0
# 33    118800.0
# 34    106600.0
# 35    100700.0
# 36    132900.0
# 37    137800.0
# 38     99300.0
# 39    107300.0
# 40     50700.0
# 41     65300.0
# 42    132500.0
# 43     57600.0
# 44    122000.0
# 45    126800.0
# 46     95400.0
# 47     66700.0
# 48     87300.0
# 49     65400.0
# dtype: float64

# %%
clean_df.insert(1,"Spread",Spread_col)
clean_df.head()
# Out:
#      Undergraduate Major    Spread  Starting Median Salary  \
# 0             Accounting  109800.0                 46000.0
# 1  Aerospace Engineering   96700.0                 57700.0
# 2            Agriculture  113700.0                 42600.0
# 3           Anthropology  104200.0                 36800.0
# 4           Architecture   85400.0                 41600.0
#
#    Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# 0                   77100.0                            42200.0
# 1                  101000.0                            64300.0
# 2                   71900.0                            36300.0
# 3                   61500.0                            33800.0
# 4                   76800.0                            50600.0
#
#    Mid-Career 90th Percentile Salary     Group
# 0                           152000.0  Business
# 1                           161000.0      STEM
# 2                           150000.0  Business
# ...

# %%
low_risk=clean_df.sort_values('Spread')
low_risk.head()
# Out:
#            Undergraduate Major   Spread  Starting Median Salary  \
# 40                     Nursing  50700.0                 54200.0
# 43         Physician Assistant  57600.0                 74300.0
# 41                   Nutrition  65300.0                 39900.0
# 49                     Spanish  65400.0                 34000.0
# 27  Health Care Administration  66400.0                 38800.0
#
#     Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# 40                   67000.0                            47600.0
# 43                   91700.0                            66400.0
# 41                   55300.0                            33900.0
# 49                   53100.0                            31000.0
# 27                   60600.0                            34600.0
#
#     Mid-Career 90th Percentile Salary     Group
# 40                            98300.0  Business
# 43                           124000.0      STEM
# ...

# %%
low_risk.tail()
# Out:
#    Undergraduate Major    Spread  Starting Median Salary  \
# 42          Philosophy  132500.0                 39900.0
# 36           Marketing  132900.0                 40800.0
# 37                Math  137800.0                 45400.0
# 22             Finance  147800.0                 47900.0
# 17           Economics  159400.0                 50100.0
#
#     Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# 42                   81200.0                            35500.0
# 36                   79600.0                            42100.0
# 37                   92400.0                            45200.0
# 22                   88300.0                            47200.0
# 17                   98600.0                            50600.0
#
#     Mid-Career 90th Percentile Salary     Group
# 42                           168000.0      HASS
# 36                           175000.0  Business
# 37                           183000.0      STEM
# ...

# %%
highest_potential_degrees=clean_df.sort_values('Mid-Career 90th Percentile Salary',ascending=False)
highest_potential_degrees[['Undergraduate Major','Mid-Career 90th Percentile Salary']].head()
# Out:
#      Undergraduate Major  Mid-Career 90th Percentile Salary
# 17             Economics                           210000.0
# 22               Finance                           195000.0
# 8   Chemical Engineering                           194000.0
# 37                  Math                           183000.0
# 44               Physics                           178000.0

# %%
low_risk[["Undergraduate Major",'Spread']].tail()
# Out:
#    Undergraduate Major    Spread
# 42          Philosophy  132500.0
# 36           Marketing  132900.0
# 37                Math  137800.0
# 22             Finance  147800.0
# 17           Economics  159400.0

# %%
clean_df=clean_df.drop('Undergraduate Major',axis=1)

# %%
pd.options.display.float_format = '{:,.2f}'.format 
clean_df.groupby('Group').mean()
# Out:
#              Spread  Starting Median Salary  Mid-Career Median Salary  \
# Group
# Business 103,958.33               44,633.33                 75,083.33
# HASS      95,218.18               37,186.36                 62,968.18
# STEM     101,600.00               53,862.50                 90,812.50
#
#           Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary
# Group
# Business                          43,566.67                         147,525.00
# HASS                              34,145.45                         129,363.64
# STEM                              56,025.00                         157,625.00
